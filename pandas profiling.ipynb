# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
 pip install pandas-profiling
# Out:
# ...
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached MarkupSafe-2.1.5.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\krish\Desktop

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '1111.PNG', 'Ai Interview prep bot', 'aug_train-checkpoint.csv', 'certificates', 'Copy of DSA-251 By Parikh Jain.xlsx', 'desktop.ini', 'django-university-management-system-main', 'excel dashboard.xlsx', 'Firefox.exe', 'krish patient.docx', 'Krishna - Chrome.lnk', 'Krishna ✨.jfif', 'krisna excel', 'Old Firefox Data', 'output.html', 'pandas profiling ipynb', 'placement.csv', 'python stock  obj', 'revis', 'some', 'sql-data-analytics-project', 'sql-ultimate-course-main', 'This PC.lnk', 'train.csv', 'Untitled.ipynb', 'Visual Studio Code.lnk', 'Zoom Workplace.lnk', '~$ish patient.docx', '~$ishna Sahu CV1.docx', '~WRL0003.tmp']

# %%
import os

for item in os.listdir(r"C:\Users\krish\Desktop"):
    print(item)
# Out:
# .ipynb_checkpoints
# 1111.PNG
# Ai Interview prep bot
# aug_train-checkpoint.csv
# certificates
# Copy of DSA-251 By Parikh Jain.xlsx
# desktop.ini
# django-university-management-system-main
# excel dashboard.xlsx
# Firefox.exe
# krish patient.docx
# Krishna - Chrome.lnk
# Krishna ✨.jfif
# krisna excel
# Old Firefox Data
# output.html
# pandas profiling ipynb
# placement.csv
# python stock  obj
# revis
# some
# sql-data-analytics-project
# sql-ultimate-course-main
# This PC.lnk
# train.csv
# Untitled.ipynb
# Visual Studio Code.lnk
# Zoom Workplace.lnk
# ~$ish patient.docx
# ~$ishna Sahu CV1.docx
# ~WRL0003.tmp

# %%
# %cd C:\Users\krish\Desktop\learn-ml-models
# Out:
# [WinError 2] The system cannot find the file specified: 'C:\\Users\\krish\\Desktop\\learn-ml-models'
# C:\Users\krish\Desktop

# %%
# !git --version
# Out:
# git version 2.55.0.windows.3

# %%
# %cd C:\Users\krish\Desktop
# !git clone https://github.com/Krishnasahu810/learn-ml-models.git
# Out:
# C:\Users\krish\Desktop
# Cloning into 'learn-ml-models'...

# %%
# %cd C:\Users\krish\Desktop\learn-ml-models
# !git status
# Out:
# C:\Users\krish\Desktop\learn-ml-models
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C225-0BFB
#
#  Directory of C:\Users\krish\Desktop\learn-ml-models
#
# 02-08-2026  00:50    <DIR>          .
# 02-08-2026  00:50    <DIR>          ..
# 02-08-2026  00:50           575,647 data visualisations.ipynb
# 02-08-2026  00:50           161,042 learn ml models.ipynb
# 02-08-2026  00:50                16 README.md
# 02-08-2026  00:50           636,685 web scrapping demo.ipynb
#                4 File(s)      1,373,390 bytes
#                2 Dir(s)   5,316,141,056 bytes free

# %%
# !dir "C:\Users\krish\Desktop\pandas profiling ipynb"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C225-0BFB
#
#  Directory of C:\Users\krish\Desktop
#
# 02-08-2026  00:51            23,719 pandas profiling ipynb
#                1 File(s)         23,719 bytes
#                0 Dir(s)   5,313,069,056 bytes free

# %%
import os

print(os.path.isfile(r"C:\Users\krish\Desktop\pandas profiling ipynb"))
print(os.path.splitext(r"C:\Users\krish\Desktop\pandas profiling ipynb"))
# Out:
# True
# ('C:\\Users\\krish\\Desktop\\pandas profiling ipynb', '')
